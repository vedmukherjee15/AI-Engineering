# %%
import os
from dotenv import load_dotenv
from scrapper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role":"user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano",messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Nice to meet you. I’m ChatGPT, and I’m here to help with a lot of things—answers, explanations, writing and editing, planning, coding, translations, and just about anything you’re curious about.\n\nA few quick ideas of what I can do:\n- Explain topics in simple terms or dive into details\n- Help write or edit emails, essays, resumes, etc.\n- Solve math problems or debug code\n- Plan a study schedule, a trip, or a project\n- Create a story, brainstorm ideas, or play a quick game\n\nWhat would you like to do today? If you’re unsure, tell me a bit about your interests or a goal you have, and I’ll tailor some options. And if you want, we can start with a quick example—like a 2-minute topic explainer or a short story prompt.'

# %%
wb = fetch_website_contents("https://introtodeeplearning.com/")
print(wb)
# Out:
# MIT Deep Learning 6.S191
#
# HOME
# (current)
# OVERVIEW
# SCHEDULE
# TEAM
# F.A.Q.
# MIT 6.S191
# Introduction to
# Deep Learning
# MIT's introductory program on deep learning methods with applications in
# vision, robotics, medicine, language, game play, art
# , and more!
# Description
# An
# efficient and high-intensity bootcamp
# designed to teach you the fundamentals of deep learning
# as quickly as possible
# !
# MIT's introductory program on deep learning methods with applications to natural language processing, computer vision, biology, and more! Students will gain foundational knowledge of deep learning algorithms, practical experience in building neural networks, and understanding of cutting-edge topics including large language models and generative AI. Program concludes with a project proposal competition with feedback from staff and panel of industry sponsors. Prerequisites assume calculus (i.e. taking derivatives) and linear algebra (i.e. matrix multiplication), we'll try to explain everything else along the way! Experience in Python is helpful but not necessary. Listeners are welcome!
# Time and Location
# Mon Jan 5 - Fri Jan 9, 2026
# Every day 1-4pm ET
# MIT Room
# 32-123
# New lectures, competitions, &  prizes!
# Schedule
# 2026 edition coming soon!
# Taught in-person at MIT — open-sourced to the world.
# Intro to Deep Learning
# Lecture 1
# Jan. 5, 2026
# [
# Slides
# ] [
# Video
# ]
# coming soon!
# Deep Sequence Modeling
# Lecture 2
# Jan. 5, 2026
# [
# Slides
# ] [
# Video
# ]
# coming soon!
# Deep Learning in Python; Music Generation
# Software Lab 1
# [
# Code
# ]
# coming soon!
# Deep Computer Vision
# Lecture 3
# Jan. 6, 2026
# [
# Slides
# ] [
# Video
# ]
# coming soon!
# Deep Generative Modeling
# Lecture 4
# Jan. 6, 2026
# [
# Slides
# ] [
# Video
# ]
# coming soon!
# Facial Detection Systems
# Software Lab 2
# [
# Paper
# ] [
# Code
# ]
# coming soon!
# Deep Reinforcement Learning
# Lecture 5
# Jan. 7, 2026
# [
# Slides
# ] [
# Video
# ]
# coming soon!
# New Frontiers
# Lecture 6
# Jan. 7, 2026
# [
# Slides
# ] [
# Video
# ]
# coming soon!
# Fine-Tune an LLM,
# You Must!
# Software Lab 3
# [
# Code
# ]
# coming soon!
# Guest Lecture
# Lecture 7

# %%
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
messages =[
    {"role": "system", "content": "You are an helpful assistant"},
    {"role": "user", "content": "What is 2+2"}
]

response = openai.chat.completions.create(model='gpt-5-nano', messages=messages)
response.choices[0].message.content
# Out:
# '4'

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix+ website}
    ]

# %%
messages_for(wb)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': "\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nMIT Deep Learning 6.S191\n\nHOME\n(current)\nOVERVIEW\nSCHEDULE\nTEAM\nF.A.Q.\nMIT 6.S191\nIntroduction to\nDeep Learning\nMIT's introductory program on deep learning methods with applications in\nvision, robotics, medicine, language, game play, art\n, and more!\nDescription\nAn\nefficient and high-intensity bootcamp\ndesigned to teach you the fundamentals of deep learning\nas quickly as possible\n!\nMIT's introductory program on deep learning methods with applications to natural language processing, computer vision, biology, and more! Students will gain foundational knowledge of deep learning algorithms, practical experience in building neural networks, and understanding of cutting-edge topics including large language models and generative AI. Program concludes with a project proposal competition with feedback from staff and panel of industry sponsors. Prerequisites assume calculus (i.e. taking derivatives) and linear algebra (i.e. matrix multiplication), we'll try to explain everything else along the way! Experience in Python is helpful but not necessary. Listeners are welcome!\nTime and Location\nMon Jan 5 - Fri Jan 9, 2026\nEvery day 1-4pm ET\nMIT Room\n32-123\nNew lectures, competitions, &  prizes!\nSchedule\n2026 edition coming soon!\nTaught in-person at MIT — open-sourced to the world.\nIntro to Deep Learning\nLecture 1\nJan. 5, 2026\n[\nSlides\n] [\nVideo\n]\ncoming soon!\nDeep Sequence Modeling\nLecture 2\nJan. 5, 2026\n[\nSlides\n] [\nVideo\n]\ncoming soon!\nDeep Learning in Python; Music Generation\nSoftware Lab 1\n[\nCode\n]\ncoming soon!\nDeep Computer Vision\nLecture 3\nJan. 6, 2026\n[\nSlides\n] [\nVideo\n]\ncoming soon!\nDeep Generative Modeling\nLecture 4\nJan. 6, 2026\n[\nSlides\n] [\nVideo\n]\ncoming soon!\nFacial Detection Systems\nSoftware Lab 2\n[\nPaper\n] [\nCode\n]\ncoming soon!\nDeep Reinforcement Learning\nLecture 5\nJan. 7, 2026\n[\nSlides\n] [\nVideo\n]\ncoming soon!\nNew Frontiers\nLecture 6\nJan. 7, 2026\n[\nSlides\n] [\nVideo\n]\ncoming soon!\nFine-Tune an LLM,\nYou Must!\nSoftware Lab 3\n[\nCode\n]\ncoming soon!\nGuest Lecture\nLecture 7"}]

# %%
def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = 'gpt-5-nano',
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://platform.openai.com/docs/pricing")
# Out:
# - This is OpenAI’s pricing hub for the API. It’s basically a catalog of every model they’ve got, plus how much you pay per token. Yes, a price list can be this long and intimidating.
#
# - Latest news/announcements: It highlights GPT-5.2 as the current/latest model, with related variants like GPT-5.2-pro and GPT-5-pro rolling in behind it.
#
# - What’s priced: Prices per 1 million tokens, broken out by input, cached input, and output tokens. There are multiple service tiers labeled Batch, Flex, Standard, and Priority, affecting how you’re billed.
#
# - Models listed: GPT-5 family (GPT-5.2, GPT-5.1, GPT-5, GPT-5-mini, GPT-5-nano), GPT-5.2-pro, GPT-5-pro, various GPT-4 variants (GPT-4.1, GPT-4o, etc.), and a bunch of “o” and mini/deep-research variants (o1, o3, o4-mini, o3-mini, etc.). Also some specialized or preview items like computer-use-preview.
#
# - Takeaway: If you’re budgeting for API usage, this page is where you’ll find who costs how much for which model and which plan. If you want the cleanest answer, you’ll need to pick a model and a tier and do the math yourself.
